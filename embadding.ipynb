# %% [markdown]
# # test.csv -> test1.csv로 새로 임베딩해서 모델 학습
# *이걸로 하려면 python test.py로 실행*

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as pd
#       2 from sentence_transformers import SentenceTransformer
#       3 from sklearn.metrics.pairwise import cosine_similarity
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# # SentenceBERT 모델 로드

# %%
model = SentenceTransformer('jhgan/ko-sroberta-multitask')

sentences = ["안녕하세요?", "한국어 문장 임베딩을 위한 버트 모델입니다."]
embeddings = model.encode(sentences)

print(embeddings)
# Out:
# [[-0.37510416 -0.7733841   0.5927707  ...  0.5792348   0.32683465
#   -0.65089625]
#  [-0.09361652 -0.181915   -0.1923081  ... -0.03165704  0.30412608
#   -0.26793545]]

# %% [markdown]
# # 데이터셋 로드
#
# 웰니스 대화 스크립트 데이터셋
#
# https://aihub.or.kr/opendata/keti-data/recognition-laguage/KETI-02-006

# %%
df = pd.read_csv('test.csv')

df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('test.csv')
#       3 df.head()
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # 전처리

# %%
df = df.drop(columns=['Unnamed: 3'])

df.head()
# Out:
#                   구분         유저  \
# 0  HeyDoctor/병원위치/병원        닥터.
# 1  HeyDoctor/병원위치/병원        병원.
# 2  HeyDoctor/병원위치/병원     주변 병원.
# 3  HeyDoctor/병원위치/병원  HeyDoctor
# 4  HeyDoctor/병원위치/병원      헤이닥터.
#
#                                                   챗봇
# 0  주변 병원을 한 눈에 볼 수 있는 HeyDoctor 페이지 입니다. (https:/...
# 1  주변 병원을 한 눈에 볼 수 있는 HeyDoctor 페이지 입니다. (https:/...
# 2  주변 병원을 한 눈에 볼 수 있는 HeyDoctor 페이지 입니다. (https:/...
# 3  주변 병원을 한 눈에 볼 수 있는 HeyDoctor 페이지 입니다. (https:/...
# 4  주변 병원을 한 눈에 볼 수 있는 HeyDoctor 페이지 입니다. (https:/...

# %%
df = df[~df['챗봇'].isna()]

df.head()
# Out:
#                   구분         유저  \
# 0  HeyDoctor/병원위치/병원        닥터.
# 1  HeyDoctor/병원위치/병원        병원.
# 2  HeyDoctor/병원위치/병원     주변 병원.
# 3  HeyDoctor/병원위치/병원  HeyDoctor
# 4  HeyDoctor/병원위치/병원      헤이닥터.
#
#                                                   챗봇
# 0  주변 병원을 한 눈에 볼 수 있는 HeyDoctor 페이지 입니다. (https:/...
# 1  주변 병원을 한 눈에 볼 수 있는 HeyDoctor 페이지 입니다. (https:/...
# 2  주변 병원을 한 눈에 볼 수 있는 HeyDoctor 페이지 입니다. (https:/...
# 3  주변 병원을 한 눈에 볼 수 있는 HeyDoctor 페이지 입니다. (https:/...
# 4  주변 병원을 한 눈에 볼 수 있는 HeyDoctor 페이지 입니다. (https:/...

# %%
df.loc[0, '유저']
# Out:
# '닥터.'

# %%
model.encode(df.loc[0, '유저'])
# Out:
# array([-3.08746845e-01, -4.05500859e-01,  8.06768239e-01, -4.08557534e-01,
#         5.29274464e-01, -2.67317712e-01,  2.69127311e-03,  1.61575004e-01,
#         6.28005207e-01,  2.87868142e-01, -4.77580249e-01, -7.50879586e-01,
#         5.38611487e-02,  9.91580263e-02, -4.43481922e-01, -1.04164191e-01,
#         1.82732508e-01,  3.26216817e-02,  5.26533425e-01, -8.05257499e-01,
#        -6.46315098e-01,  9.15777460e-02,  1.28406930e+00,  1.00877687e-01,
#        -1.46725237e-01, -3.15160096e-01,  1.51938021e-01,  7.37925991e-02,
#         2.26010516e-01,  2.30430976e-01, -7.86936879e-01, -3.82788628e-02,
#        -8.33713710e-01,  2.34134138e-01,  1.01159227e+00,  3.39505792e-01,
#        -1.87270552e-01, -3.97869051e-01, -8.62908363e-01,  1.17067091e-01,
#        -3.02893728e-01,  2.28146538e-01, -5.35968423e-01,  5.04836217e-02,
#         6.23851381e-02, -7.91519463e-01, -6.05692148e-01,  2.34382018e-01,
#        -7.04617739e-01, -3.75699401e-01,  2.84801811e-01, -1.11145663e+00,
#         2.36561626e-01,  6.81230903e-01,  3.34043384e-01,  2.87311766e-02,
#         6.98036671e-01, -6.21162534e-01,  5.04390478e-01, -6.12986684e-01,
#         9.53320190e-02, -3.34241092e-01,  1.62105888e-01,  1.93540722e-01,
#        -4.79972690e-01, -5.82685843e-02,  1.72537401e-01, -6.91164970e-01,
#        -6.18999079e-02,  3.75767276e-02, -4.41500425e-01, -7.36487061e-02,
#        -6.27546012e-02,  5.26215017e-01,  6.91883564e-01, -1.63172483e-01,
#         5.47752142e-01, -1.39358774e-01, -7.86051512e-01, -4.75730300e-01,
#        -1.71825632e-01,  3.61401260e-01, -9.11676526e-01,  3.88654858e-01,
#        -4.32613522e-01, -1.36418700e-01,  1.28322661e-01,  3.14779878e-01,
#         2.20035642e-01, -1.50817841e-01, -6.14962339e-01,  2.29308814e-01,
#        -4.77027118e-01,  2.26583090e-02,  3.22897911e-01, -1.49362683e-01],
#       dtype=float32)

# %% [markdown]
# # 유저 대화내용 인코딩

# %%
df['embedding'] = pd.Series([[]] * len(df)) # dummy

df['embedding'] = df['유저'].map(lambda x: list(model.encode(x)))

df.head()
# Out:
#                   구분         유저  \
# 0  HeyDoctor/병원위치/병원        닥터.
# 1  HeyDoctor/병원위치/병원        병원.
# 2  HeyDoctor/병원위치/병원     주변 병원.
# 3  HeyDoctor/병원위치/병원  HeyDoctor
# 4  HeyDoctor/병원위치/병원      헤이닥터.
#
#                                                   챗봇  \
# 0  주변 병원을 한 눈에 볼 수 있는 HeyDoctor 페이지 입니다. (https:/...
# 1  주변 병원을 한 눈에 볼 수 있는 HeyDoctor 페이지 입니다. (https:/...
# 2  주변 병원을 한 눈에 볼 수 있는 HeyDoctor 페이지 입니다. (https:/...
# 3  주변 병원을 한 눈에 볼 수 있는 HeyDoctor 페이지 입니다. (https:/...
# 4  주변 병원을 한 눈에 볼 수 있는 HeyDoctor 페이지 입니다. (https:/...
#
#                                            embedding
# 0  [-0.30874684, -0.40550086, 0.80676824, -0.4085...
# 1  [-0.22459042, -0.42874175, 0.11615643, -0.0463...
# 2  [-0.019309644, -0.31391862, 0.052716993, -0.14...
# 3  [0.1374908, -0.66181743, 0.350293, 0.39851657,...
# 4  [-0.21461569, -0.45300138, 0.58759004, 0.09304...

# %%
df.to_csv('test1.csv', index=False)

# %% [markdown]
# # 간단한 챗봇

# %%
text = '고열'

embedding = model.encode(text)

# %%
df['distance'] = df['embedding'].map(lambda x: cosine_similarity([embedding], [x]).squeeze())

df.head()
# Out:
#                   구분         유저  \
# 0  HeyDoctor/병원위치/병원        닥터.
# 1  HeyDoctor/병원위치/병원        병원.
# 2  HeyDoctor/병원위치/병원     주변 병원.
# 3  HeyDoctor/병원위치/병원  HeyDoctor
# 4  HeyDoctor/병원위치/병원      헤이닥터.
#
#                                                   챗봇  \
# 0  주변 병원을 한 눈에 볼 수 있는 HeyDoctor 페이지 입니다. (https:/...
# 1  주변 병원을 한 눈에 볼 수 있는 HeyDoctor 페이지 입니다. (https:/...
# 2  주변 병원을 한 눈에 볼 수 있는 HeyDoctor 페이지 입니다. (https:/...
# 3  주변 병원을 한 눈에 볼 수 있는 HeyDoctor 페이지 입니다. (https:/...
# 4  주변 병원을 한 눈에 볼 수 있는 HeyDoctor 페이지 입니다. (https:/...
#
#                                            embedding  distance
# 0  [-0.30874684, -0.40550086, 0.80676824, -0.4085...  0.466053
# 1  [-0.22459042, -0.42874175, 0.11615643, -0.0463...  0.443668
# 2  [-0.019309644, -0.31391862, 0.052716993, -0.14...  0.428875
# 3  [0.1374908, -0.66181743, 0.350293, 0.39851657,...  0.302433
# 4  [-0.21461569, -0.45300138, 0.58759004, 0.09304...  0.415574

# %%
answer = df.loc[df['distance'].idxmax()]

print('구분', answer['구분'])
print('유사한 질문', answer['유저'])
print('챗봇 답변', answer['챗봇'])
print('유사도', answer['distance'])
# Out:
# 구분 증상/머리
# 유사한 질문 (고열)열이 38.5도 이상이에요.
# 챗봇 답변 고열은 오래 지속되면 위험할 수 있으니 반드시 가까운 병원에 내원하세요. (https://www.naver.com/)
# 유사도 0.6530831456184387
